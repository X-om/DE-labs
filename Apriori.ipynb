# %%
# !pip install mlxtend

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# Create the dataset
data = {'Transaction ID': [1, 2, 3, 4, 5],
        'Items Bought': [['Bread', 'Butter', 'Milk'],
                         ['Bread', 'Butter'],
                         ['Beer', 'Cookies', 'Diapers'],
                         ['Milk', 'Diapers', 'Bread', 'Butter'],
                         ['Beer', 'Diapers']]}

# Convert into a DataFrame
df = pd.DataFrame(data)

# List of transactions
transactions = df['Items Bought'].tolist()

# Initialize TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm to find frequent itemsets with a minimum support of 0.001
frequent_itemsets = apriori(df_encoded, min_support=0.001, use_colnames=True)

# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets[1:10])
print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#    support          itemsets
# 1      0.6           (Bread)
# 2      0.6          (Butter)
# 3      0.2         (Cookies)
# 4      0.6         (Diapers)
# 5      0.4            (Milk)
# 6      0.2   (Cookies, Beer)
# 7      0.4   (Diapers, Beer)
# 8      0.6   (Butter, Bread)
# 9      0.2  (Bread, Diapers)
#
# Association Rules:
#                  antecedents               consequents  antecedent support  \
# 0                  (Cookies)                    (Beer)                 0.2
# 1                     (Beer)                 (Cookies)                 0.4
# 2                  (Diapers)                    (Beer)                 0.6
# 3                     (Beer)                 (Diapers)                 0.4
# 4                   (Butter)                   (Bread)                 0.6
# 5                    (Bread)                  (Butter)                 0.6
# 6                    (Bread)                    (Milk)                 0.6
# ...

# %%
# Let's first check the contents of the CSV file.
import pandas as pd

# Load the uploaded CSV file
from google.colab import files
uploaded = files.upload()

df_csv_new = pd.read_csv(next(iter(uploaded)))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      <input type="file" id="files-fbdf53e5-4c0a-47cc-b0b8-9ea0c4720824" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbdf53e5-4c0a-47cc-b0b8-9ea0c4720824">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# ...

# %%
print("CSV File Contents:")
print(df_csv_new.head())
# Out:
# CSV File Contents:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
transactions_csv = df_csv_new.apply(lambda row: row.dropna().tolist(), axis=1).tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions_csv).transform(transactions_csv)
df_encoded_csv = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets_csv = apriori(df_encoded_csv, min_support=0.001, use_colnames=True)

rules_csv = association_rules(frequent_itemsets_csv, metric="lift", min_threshold=1)

print("\nFrequent Itemsets:")
print(frequent_itemsets_csv[1:10])
print("\nAssociation Rules:")
print(rules_csv)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Frequent Itemsets:
#     support             itemsets
# 1  0.008800  (antioxydant juice)
# 2  0.004667          (asparagus)
# 3  0.033200            (avocado)
# 4  0.004533        (babies food)
# 5  0.008667              (bacon)
# 6  0.010800     (barbecue sauce)
# 7  0.014267          (black tea)
# 8  0.009200        (blueberries)
# 9  0.011467         (body spray)
#
# Association Rules:
#                antecedents                                        consequents  \
# 0                (almonds)                                          (avocado)
# 1                (avocado)                                          (almonds)
# ...
